# %%
import numpy as np
import math

# %%
#Metode leleran sederhana
fungsi = input("Masukan fungsi : ")
def f(x):
  return eval(fungsi)

gx = input("Masukan fungsi : ")
def g(x):
  return eval(gx)
# Out:
# Masukan fungsi : x**2-2*x-3
# Masukan fungsi : (2*x+3)**0.5

# %%
X = float(input("Masukan tebakan awal : "))
# Out:
# Masukan tebakan awal : 4

# %%
g(3)
# Out:
# 3.0

# %%
e = float(input("Masukan toleransi maksimum : "))
N = int(input("Masukan iterasi maksimum : "))
# Out:
# Masukan toleransi maksimum : 0.00000000000000000001
# Masukan iterasi maksimum : 100

# %%
print("|X\t\t\t| Xr\t\t\t| |Xr-X|\t\t| G(X)\t\t\t|")
print("================================================================================================|")
for i in range(N):
  Xr = g(X)
  print("|%0.20f |%-0.20f |%-0.20f |%-0.20f |" %(X,Xr,np.abs(Xr-X),g(X)))
  if np.abs((Xr-X)) <= e:
    print("================================================================================================|")
    print("Akar taksiran : ",Xr)
    break
  elif i > N-1:   
    print("================================================================================================|")
    print("Leleran Divergen")
    break
  X = Xr
print("================================================================================================|")
# Out:
# |X			| Xr			| |Xr-X|		| G(X)			|
# ================================================================================================|
# |4.00000000000000000000 |3.31662479035539980998 |0.68337520964460019002 |3.31662479035539980998 |
# |3.31662479035539980998 |3.10374766704878890522 |0.21287712330661090476 |3.10374766704878890522 |
# |3.10374766704878890522 |3.03438549530173862223 |0.06936217174705028299 |3.03438549530173862223 |
# |3.03438549530173862223 |3.01144001942649985892 |0.02294547587523876331 |3.01144001942649985892 |
# |3.01144001942649985892 |3.00381091929119259376 |0.00762910013530726516 |3.00381091929119259376 |
# |3.00381091929119259376 |3.00127003759781407766 |0.00254088169337851610 |3.00127003759781407766 |
# |3.00127003759781407766 |3.00042331599986544788 |0.00084672159794862978 |3.00042331599986544788 |
# |3.00042331599986544788 |3.00014110201499217823 |0.00028221398487326965 |3.00014110201499217823 |
# ...

# %%
np.abs(Xr-X) < e
# Out:
# False
