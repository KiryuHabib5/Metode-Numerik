# %%
import numpy as np
import math

# %%
a = np.array([2,4,0,-18])
n = len(a)-1
pangkat = n
x = 5

# %%
for i in range(n-1):
  if i==0:
    px = a[i]*pangkat*x + a[i+1]*(pangkat-1)
    print(a[i],"*",pangkat,"*",x," + ",a[i+1],"*",(pangkat-1))
    pangkat-=1
  else:
    print(px ,"*", x ,"+", a[i+1],"*",(pangkat-1))
    px = px * x + a[i+1]*(pangkat-1)
    pangkat-=1
print(px)
# Out:
# 2 * 3 * 5  +  4 * 2
# 38 * 5 + 0 * 1
# 190

# %%
def dP(x):
  input_user = input("Masukan koef dari variabel paling tinggi (pisahkan dengan koma) : ")
  a = np.array(input_user.split(','),dtype=np.float64)
  n = len(a)-1
  pangkat = n
  for i in range(n-1):
    if i==0:
      px = a[i]*pangkat*x + a[i+1]*(pangkat-1)
      print(a[i],"*",pangkat,"*",x," + ",a[i+1],"*",(pangkat-1))
      pangkat-=1
    else:
      print(px ,"*", x ,"+", a[i+1],"*",(pangkat-1))
      px = px * x + a[i+1]*(pangkat-1)
      pangkat-=1
  return px

# %%
dP(5)
# Out:
# Masukan koef dari variabel paling tinggi (pisahkan dengan koma) : 2,4,0,-18
# 2.0 * 3 * 5  +  4.0 * 2
# 38.0 * 5 + 0.0 * 1
# 190.0

# %%
koef
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-39328fc0360d> in <module>()
# ----> 1 koef
#
# NameError: name 'koef' is not defined
