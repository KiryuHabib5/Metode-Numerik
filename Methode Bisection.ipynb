# %%
import numpy as np
import math

# %%
#membuat fungsi
fungsi = input("Masukan persamaan : ")
def f(x):
  return eval(fungsi)
# Out:
# Masukan persamaan : x**3+4*x**2-10

# %%
while True:  
  x1 = float(input("Masukan tebakan akar pertama : "))
  x2 = float(input("Masukan tebakan akar kedua   : "))
  if f(x1)*f(x2) < 0:
    break
  else:
    print(f(x1)*f(x2))
    print("Kemungkinan tidak ada akar pada interval akar-akar yang kamu masukkan, Silahkan masukan lagi")
# Out:
# Masukan tebakan akar pertama : 1
# Masukan tebakan akar kedua   : 2

# %%
e = float(input("Masukan toleransi maksimum    : "))
N = int(input("Masukan jumlah iterasi maksimum : "))
# Out:
# Masukan toleransi maksimum    : 0.0000000001
# Masukan jumlah iterasi maksimum : 1000000000

# %%
x1
# Out:
# 1.3652300133835524

# %%
print("|x1\t\t\t|x2\t\t\t|xr\t\t\t|iterasi|")
print("================================================================================|")
for i in range(N):
  xr = (x1+x2)/2
  #print(x1, " \t%-20s", x2, " \t%-20s", xr, " \t%-20s", i+1)
  print("|%0.20f |%-0.20f |%-0.20f |%-d\t|" %(x1,x2,xr,i+1))
  if f(x1)*f(xr) < 0:
    x2 = xr
  elif f(x1)*f(xr)== 0:
    print("Akar = ", xr)
  else:
    x1 = xr
  if np.abs(x2-x1) < e:
    break
print("================================================================================|")
# Out:
# |x1			|x2			|xr			|iterasi|
# ================================================================================|
# |1.00000000000000000000 |2.00000000000000000000 |1.50000000000000000000 |1	|
# |1.00000000000000000000 |1.50000000000000000000 |1.25000000000000000000 |2	|
# |1.25000000000000000000 |1.50000000000000000000 |1.37500000000000000000 |3	|
# |1.25000000000000000000 |1.37500000000000000000 |1.31250000000000000000 |4	|
# |1.31250000000000000000 |1.37500000000000000000 |1.34375000000000000000 |5	|
# |1.34375000000000000000 |1.37500000000000000000 |1.35937500000000000000 |6	|
# |1.35937500000000000000 |1.37500000000000000000 |1.36718750000000000000 |7	|
# |1.35937500000000000000 |1.36718750000000000000 |1.36328125000000000000 |8	|
# |1.36328125000000000000 |1.36718750000000000000 |1.36523437500000000000 |9	|
# |1.36328125000000000000 |1.36523437500000000000 |1.36425781250000000000 |10	|
# |1.36425781250000000000 |1.36523437500000000000 |1.36474609375000000000 |11	|
# |1.36474609375000000000 |1.36523437500000000000 |1.36499023437500000000 |12	|
# |1.36499023437500000000 |1.36523437500000000000 |1.36511230468750000000 |13	|
# |1.36511230468750000000 |1.36523437500000000000 |1.36517333984375000000 |14	|
# |1.36517333984375000000 |1.36523437500000000000 |1.36520385742187500000 |15	|
# |1.36520385742187500000 |1.36523437500000000000 |1.36521911621093750000 |16	|
# |1.36521911621093750000 |1.36523437500000000000 |1.36522674560546875000 |17	|
# |1.36522674560546875000 |1.36523437500000000000 |1.36523056030273437500 |18	|
# |1.36522674560546875000 |1.36523056030273437500 |1.36522865295410156250 |19	|
# |1.36522865295410156250 |1.36523056030273437500 |1.36522960662841796875 |20	|
# |1.36522960662841796875 |1.36523056030273437500 |1.36523008346557617188 |21	|
# |1.36522960662841796875 |1.36523008346557617188 |1.36522984504699707031 |22	|
# |1.36522984504699707031 |1.36523008346557617188 |1.36522996425628662109 |23	|
# |1.36522996425628662109 |1.36523008346557617188 |1.36523002386093139648 |24	|
# |1.36522996425628662109 |1.36523002386093139648 |1.36522999405860900879 |25	|
# |1.36522999405860900879 |1.36523002386093139648 |1.36523000895977020264 |26	|
# |1.36523000895977020264 |1.36523002386093139648 |1.36523001641035079956 |27	|
# |1.36523000895977020264 |1.36523001641035079956 |1.36523001268506050110 |28	|
# |1.36523001268506050110 |1.36523001641035079956 |1.36523001454770565033 |29	|
# |1.36523001268506050110 |1.36523001454770565033 |1.36523001361638307571 |30	|
# |1.36523001268506050110 |1.36523001361638307571 |1.36523001315072178841 |31	|
# |1.36523001315072178841 |1.36523001361638307571 |1.36523001338355243206 |32	|
# |1.36523001338355243206 |1.36523001361638307571 |1.36523001349996775389 |33	|
# |1.36523001338355243206 |1.36523001349996775389 |1.36523001344176009297 |34	|
# ================================================================================|
